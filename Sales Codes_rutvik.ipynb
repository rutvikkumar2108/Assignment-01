# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/ENTER NAME/Downloads/Sample_Data.csv")

# %%
df.columns
# Out:
# Index(['S.NO', 'District Name', 'Depot Code', 'Mandal_Name',
#        'Retailer Category', 'Category  A_Total Bottle',
#        'Category  A_Sale Value', 'Category  B_Total Bottle',
#        'Category  B_Sale Value', 'Category  C_Total Bottle',
#        'Category  C_Sale Value', 'Total Volume', 'Total Sale Value', 'Month',
#        'Year', 'Unnamed: 15'],
#       dtype='object')

# %%
#2
df[['District Name','Total Sale Value']]
# Out:
#       District Name  Total Sale Value
# 0        District-C         4151640.0
# 1        District-C         4525380.0
# 2        District-A           80400.0
# 3        District-C         4910700.0
# 4        District-C         5339240.0
# ...             ...               ...
# 66317    District-G        11833800.0
# 66318    District-G        11780800.0
# 66319    District-G        12523320.0
# 66320    District-G        15744860.0
# 66321    District-G        15314600.0
#
# [66322 rows x 2 columns]

# %%
df.groupby(['District Name','Mandal_Name'])

# %%
np.corrcoef(df['Category  A_Sale Value'],df['Category  B_Sale Value'])
# Out:
# array([[1.        , 0.44876032],
#        [0.44876032, 1.        ]])

# %% [markdown]
# ## 2.What is correlation coefficient between Category A sales amount and Category B Sales amount?
# ### 0.44876032

# %%
df['Mandal_Name'].unique()
# Out:
# array(['Mandal 63', 'Mandal 25', 'Mandal 1', 'Mandal 59', 'Mandal 16',
#        'Mandal 40', 'Mandal 49', 'Mandal 21', 'Mandal 7', 'Mandal 64',
#        'Mandal 2', 'Mandal 18', 'Mandal 42', 'Mandal 51', 'Mandal 65',
#        'Mandal 43', 'Mandal 3', 'Mandal 26', 'Mandal 66', 'Mandal 39',
#        'Mandal 27', 'Mandal 67', 'Mandal 68', 'Mandal 4', 'Mandal 35',
#        'Mandal 30', 'Mandal 69', 'Mandal 70', 'Mandal 5', 'Mandal 6',
#        'Mandal 71', 'Mandal 8', 'Mandal 15', 'Mandal 72', 'Mandal 73',
#        'Mandal 29', 'Mandal 9', 'Mandal 46', 'Mandal 10', 'Mandal 74',
#        'Mandal 75', 'Mandal 11', 'Mandal 76', 'Mandal 34', 'Mandal 28',
#        'Mandal 12', 'Mandal 13', 'Mandal 57', 'Mandal 77', 'Mandal 14',
#        'Mandal 50', 'Mandal 78', 'Mandal 79', 'Mandal 17', 'Mandal 80',
#        'Mandal 31', 'Mandal 58', 'Mandal 19', 'Mandal 81', 'Mandal 82',
#        'Mandal 83', 'Mandal 20', 'Mandal 84', 'Mandal 85', 'Mandal 22',
# ...

# %%
df_3=df[((df['Month']==3) | (df['Month']==4)| (df['Month']==5))& (df['Year']==2022)]

# %%
df_3.head(5)
# Out:
#       S.NO District Name  Depot Code Mandal_Name Retailer Category  \
# 9   1452.0    District-E        80.0    Mandal 1               GRO
# 10  1563.0    District-E        80.0    Mandal 1               GRO
# 13  1454.0    District-E        80.0    Mandal 1               GRO
# 22   677.0    District-C        84.0   Mandal 63               GRO
# 28  1565.0    District-E        80.0    Mandal 1               GRO
#
#     Category  A_Total Bottle  Category  A_Sale Value  \
# 9                    31944.0               5726460.0
# 10                   59672.0              10361820.0
# 13                   60006.0              11249820.0
# 22                   29462.0               4836400.0
# 28                   74372.0              12743840.0
#
#     Category  B_Total Bottle  Category  B_Sale Value  \
# 9                     8166.0               1583320.0
# 10                   10258.0               2003420.0
# 13                   11478.0               2227100.0
# ...

# %%
df_4=df_3[['District Name','Total Volume']]

# %%
df_4.head(5)
# Out:
#    District Name  Total Volume
# 9     District-E       40156.0
# 10    District-E       69930.0
# 13    District-E       71550.0
# 22    District-C       32186.0
# 28    District-E       88836.0

# %%
df_5=df_4.groupby(by='District Name').sum()
df_5.sort_values(by='Total Volume', ascending=False)
# Out:
#                Total Volume
# District Name
# District-C       78959878.0
# District-J       74601746.0
# District-L       70955206.0
# District-D       63562630.0
# District-E       59088018.0
# District-B       58089256.0
# District-H       51613202.0
# District-G       46714122.0
# District-I       43699122.0
# District-K       43278760.0
# District-M       43022512.0
# District-A       41014448.0
# District-F       40838772.0

# %% [markdown]
# ## 3. Which district has highest sale volume in Q2 2022(April, May, June)?
# #### District-C

# %%
df_3[['District Name','Total Volume']].sort_values(by='Total Volume', ascending=False)
# Out:
#       District Name  Total Volume
# 25393    District-H      219770.0
# 223      District-K      218532.0
# 52601    District-J      215240.0
# 25432    District-H      213174.0
# 28519    District-J      209928.0
# ...             ...           ...
# 43460    District-G        2264.0
# 62409    District-H        2058.0
# 15261    District-D        1430.0
# 12735    District-K         562.0
# 7418     District-G         398.0
#
# [9680 rows x 2 columns]

# %%
df[df['District Name']=='District-C'].sort_values(by='Category  B_Sale Value', ascending=False)[['Month']]
# Out:
#        Month
# 19708    6.0
# 19714    5.0
# 61215    5.0
# 19431    3.0
# 19702    5.0
# ...      ...
# 13221   10.0
# 45835   11.0
# 19419    9.0
# 42      11.0
# 50626    8.0
#
# [7950 rows x 1 columns]

# %%
df.head()
# Out:
#      S.NO District Name  Depot Code Mandal_Name Retailer Category  \
# 0   672.0    District-C        84.0   Mandal 63               GRO
# 1   660.0    District-C        84.0   Mandal 63               GRO
# 2  2783.0    District-A        74.0   Mandal 25     Walk In Store
# 3   667.0    District-C        84.0   Mandal 63               GRO
# 4   610.0    District-C        84.0   Mandal 63               GRO
#
#    Category  A_Total Bottle  Category  A_Sale Value  Category  B_Total Bottle  \
# 0                   20974.0               3890320.0                    1228.0
# 1                   22136.0               4254300.0                    1306.0
# 2                      92.0                 65340.0                      70.0
# 3                   23132.0               4554100.0                    1698.0
# 4                   25144.0               4832480.0                    2442.0
#
#    Category  B_Sale Value  Category  C_Total Bottle  Category  C_Sale Value  \
# ...

# %%
q3_2021_sales=df[(df['Year']==2021) & ((df['Month']==7) |(df['Month']==8) |(df['Month']==9) )][['Retailer Category','Total Sale Value']]

# %%
sales21=q3_2021_sales.groupby(by='Retailer Category').sum()
sales21
# Out:
#                    Total Sale Value
# Retailer Category
# GRO                    1.058165e+11
# Tourism Outlet         1.871395e+09
# Tourism Walkin         9.326538e+08
# Walk In Store          1.134957e+09

# %%
q3_2022_sales=df[(df['Year']==2022) & ((df['Month']==7) |(df['Month']==8) |(df['Month']==9))][['Retailer Category','Total Sale Value']]
sales22=q3_2022_sales.groupby(by='Retailer Category').sum()
sales22
# Out:
#                    Total Sale Value
# Retailer Category
# GRO                    1.118862e+11
# Tourism Outlet         6.140541e+09
# Tourism Walkin         4.696812e+09
# Walk In Store          1.050938e+09

# %%
growth=(sales22-sales21)*100/sales21
growth
# Out:
#                    Total Sale Value
# Retailer Category
# GRO                        5.736057
# Tourism Outlet           228.126344
# Tourism Walkin           403.596492
# Walk In Store             -7.402815

# %%
import matplotlib.pyplot as plt

# %%
sales21.rename({'Total Sale Value':'Q3 2021 sales'}, axis=1, inplace=True)

# %%
sales22.rename({'Total Sale Value':'Q3 2022 sales'}, axis=1, inplace=True)

# %%
sales21.reset_index(inplace=True)

# %%
sales22.reset_index(inplace=True)

# %%
sales_data = sales21.merge(sales22)

# %%
sales_data
# Out:
#   Retailer Category  Q3 2021 sales  Q3 2022 sales
# 0               GRO   1.058165e+11   1.118862e+11
# 1    Tourism Outlet   1.871395e+09   6.140541e+09
# 2    Tourism Walkin   9.326538e+08   4.696812e+09
# 3     Walk In Store   1.134957e+09   1.050938e+09

# %%
import seaborn as sns

# %%
plt.figure()
sales_data.plot(x="Retailer Category", y=["Q3 2021 sales", "Q3 2022 sales"], kind="bar")
plt.title('Retailer wise sales for 2021 and 2022')
# Out:
# Text(0.5, 1.0, 'Retailer wise sales for 2021 and 2022')

# %% [markdown]
# ## 4.What is the growth rate of sale volume from Q3 2021 to Q3 2022? Retailer Category Wise
# ### GRO -> 5.736057
# ### Tourism Outlet -> 228.126344
# ### Tourism Walkin -> 403.596492
# ### Walk In Store -> -7.402815

# %%
cat_a=df[['Category  A_Total Bottle','Month','Year']]

# %%
cat_a.head(5)
# Out:
#    Category  A_Total Bottle  Month    Year
# 0                   20974.0   11.0  2021.0
# 1                   22136.0    8.0  2021.0
# 2                      92.0    9.0  2021.0
# 3                   23132.0    9.0  2021.0
# 4                   25144.0    4.0  2021.0

# %%
cat_a.shape
# Out:
# (66322, 3)

# %%
cat_a_2021=cat_a[cat_a['Year']==2021]

# %%
cat_a.shape
# Out:
# (66322, 3)

# %%
cat_a_2021=cat_a_2021[['Category  A_Total Bottle','Month']]

# %%
cat_a_2021.head(5)
# Out:
#    Category  A_Total Bottle  Month
# 0                   20974.0   11.0
# 1                   22136.0    8.0
# 2                      92.0    9.0
# 3                   23132.0    9.0
# 4                   25144.0    4.0

# %%
cat_a_2021=cat_a_2021.groupby(by='Month').sum()

# %%
cat_a_2022=cat_a[cat_a['Year']==2022]

# %%
cat_a_2022=cat_a_2022[['Category  A_Total Bottle','Month']]

# %%
cat_a_2022=cat_a_2022.groupby(by='Month').sum()

# %%
cat_a_final=pd.concat([cat_a_2021,cat_a_2022],axis=0)

# %%
cat_a_final
# Out:
#        Category  A_Total Bottle
# Month
# 4.0                 144467170.0
# 5.0                 153239472.0
# 6.0                 166902556.0
# 7.0                 163130154.0
# 8.0                 166841316.0
# 9.0                 159975738.0
# 10.0                166517054.0
# 11.0                152529342.0
# 12.0                185037688.0
# 1.0                 218953264.0
# 2.0                 196022862.0
# 3.0                 209566582.0
# 4.0                 203833552.0
# 5.0                 231125560.0
# 6.0                 221930880.0
# 7.0                 227504590.0
# 8.0                 232586076.0
# 9.0                 218451064.0
# 10.0                220726048.0
# 11.0                198756520.0
# 12.0                226902624.0

# %%
cat_a_final['last_month_sale']=cat_a_final['Category  A_Total Bottle'].shift(+1)
cat_a_final['last_2_month_sale']=cat_a_final['Category  A_Total Bottle'].shift(+2)
cat_a_final['last_3_month_sale']=cat_a_final['Category  A_Total Bottle'].shift(+3)
cat_a_final['last_4_month_sale']=cat_a_final['Category  A_Total Bottle'].shift(+4)

# %%
cat_a_final
# Out:
#        Category  A_Total Bottle  last_month_sale  last_2_month_sale  \
# Month
# 4.0                 144467170.0              NaN                NaN
# 5.0                 153239472.0      144467170.0                NaN
# 6.0                 166902556.0      153239472.0        144467170.0
# 7.0                 163130154.0      166902556.0        153239472.0
# 8.0                 166841316.0      163130154.0        166902556.0
# 9.0                 159975738.0      166841316.0        163130154.0
# 10.0                166517054.0      159975738.0        166841316.0
# 11.0                152529342.0      166517054.0        159975738.0
# 12.0                185037688.0      152529342.0        166517054.0
# 1.0                 218953264.0      185037688.0        152529342.0
# 2.0                 196022862.0      218953264.0        185037688.0
# 3.0                 209566582.0      196022862.0        218953264.0
# 4.0                 203833552.0      209566582.0        196022862.0
# ...

# %%
cat_a_final=cat_a_final.dropna()

# %%
x=cat_a_final[['last_month_sale','last_2_month_sale','last_3_month_sale','last_4_month_sale']]

# %%
y=cat_a_final['Category  A_Total Bottle']

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
## HYPER PARAMETER OPTMIZATION

n_estimators=[100,500,900,1100,1500]
max_depth= [2,3,5,10,15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

hyperparameter_grid={
    'n_estimators':n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
}

import xgboost

regressor=xgboost.XGBRegressor()

random_cv= RandomizedSearchCV(estimator=regressor,
           param_distributions=hyperparameter_grid,
           cv=5,n_iter=50,
           scoring='neg_mean_absolute_error',n_jobs=4,
           verbose=5,
           return_train_score= True,
           random_state=42)

# %%
random_cv.fit(x,y)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [00:20:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=None, gpu_id=-1,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=15,
#              max_leaves=None, min_child_weight=4, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=0,
#              num_parallel_tree=None, predictor=None, random_state=0,
#              reg_alpha=0, reg_lambda=0, ...)

# %%
random_cv.best_params_
# Out:
# {'n_estimators': 100,
#  'min_child_weight': 4,
#  'max_depth': 15,
#  'learning_rate': 0.05,
#  'booster': 'gblinear',
#  'base_score': 0.25}

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=45)

# %%
XGBC = XGBRegressor(base_score=0.75, booster='gblinear', callbacks=None,
             colsample_bylevel=None, colsample_bynode=None,
             colsample_bytree=None, early_stopping_rounds=None,
             enable_categorical=False, eval_metric=None, gamma=None, gpu_id=-1,
             grow_policy=None, importance_type=None,
             interaction_constraints=None, learning_rate=0.05, max_bin=None,
             max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
             max_leaves=None, min_child_weight=2,
             monotone_constraints=None, n_estimators=100, n_jobs=0,
             num_parallel_tree=None, predictor=None, random_state=0,
             reg_alpha=0, reg_lambda=0)
XGBC.fit(x_train,y_train)
y_pred = XGBC.predict(x_test)
# Out:
# [00:20:12] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
## For january
x3=pd.DataFrame(data=[218451064.0,220726048.0,198756520.0,226902624.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([2.199138e+08], dtype=float32)

# %%
## For February 
x3=pd.DataFrame(data=[2.1998082e+08,218451064.0,220726048.0,198756520.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([2.1838189e+08], dtype=float32)

# %%
## For march 
x3=pd.DataFrame(data=[2.1835141e+08,2.1998082e+08,218451064.0,220726048.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([2.2226235e+08], dtype=float32)

# %%
cat_b=df[['Category  B_Total Bottle','Month','Year']]
cat_b_2021=cat_b[cat_b['Year']==2021] 
cat_b_2021=cat_b_2021[['Category  B_Total Bottle','Month']]
cat_b_2021=cat_b_2021.groupby(by='Month').sum()
cat_b_2022=cat_b[cat_b['Year']==2022] 
cat_b_2022=cat_b_2022[['Category  B_Total Bottle','Month']]
cat_b_2022=cat_b_2022.groupby(by='Month').sum()
cat_b_final=pd.concat([cat_b_2021,cat_b_2022],axis=0)

cat_b_final['last_month_sale']=cat_b_final['Category  B_Total Bottle'].shift(+1)
cat_b_final['last_2_month_sale']=cat_b_final['Category  B_Total Bottle'].shift(+2)
cat_b_final['last_3_month_sale']=cat_b_final['Category  B_Total Bottle'].shift(+3)
cat_b_final['last_4_month_sale']=cat_b_final['Category  B_Total Bottle'].shift(+4)

cat_b_final=cat_b_final.dropna()

x=cat_b_final[['last_month_sale','last_2_month_sale','last_3_month_sale','last_4_month_sale']]
y=cat_b_final['Category  B_Total Bottle']

# %%
## HYPER PARAMETER OPTMIZATION

n_estimators=[100,500,900,1100,1500]
max_depth= [2,3,5,10,15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

hyperparameter_grid={
    'n_estimators':n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
}

import xgboost

regressor=xgboost.XGBRegressor()

random_cv= RandomizedSearchCV(estimator=regressor,
           param_distributions=hyperparameter_grid,
           cv=5,n_iter=50,
           scoring='neg_mean_absolute_error',n_jobs=4,
           verbose=5,
           return_train_score= True,
           random_state=42)

# %%
random_cv.fit(x,y)
random_cv.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [00:21:07] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.25, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=None, gpu_id=-1,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.15, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=45)

# %%
XGBC = XGBRegressor(base_score=0.25, booster='gblinear', callbacks=None,
             colsample_bylevel=None, colsample_bynode=None,
             colsample_bytree=None, early_stopping_rounds=None,
             enable_categorical=False, eval_metric=None, gamma=None, gpu_id=-1,
             grow_policy=None, importance_type=None,
             interaction_constraints=None, learning_rate=0.15, max_bin=None,
             max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
             max_leaves=None, min_child_weight=2,
             monotone_constraints=None, n_estimators=100, n_jobs=0,
             num_parallel_tree=None, predictor=None, random_state=0,
             reg_alpha=0, reg_lambda=0)
XGBC.fit(x_train,y_train)
y_pred = XGBC.predict(x_test)
# Out:
# [00:21:08] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
cat_b_final
# Out:
#        Category  B_Total Bottle  last_month_sale  last_2_month_sale  \
# Month
# 8.0                  14209718.0       12905718.0         11840942.0
# 9.0                  12455794.0       14209718.0         12905718.0
# 10.0                 13683750.0       12455794.0         14209718.0
# 11.0                  9722584.0       13683750.0         12455794.0
# 12.0                 11622726.0        9722584.0         13683750.0
# 1.0                  13901032.0       11622726.0          9722584.0
# 2.0                  14160684.0       13901032.0         11622726.0
# 3.0                  18872226.0       14160684.0         13901032.0
# 4.0                  23976906.0       18872226.0         14160684.0
# 5.0                  27863130.0       23976906.0         18872226.0
# 6.0                  26206920.0       27863130.0         23976906.0
# 7.0                  18757900.0       26206920.0         27863130.0
# 8.0                  18770424.0       18757900.0         26206920.0
# ...

# %%
## For january
x3=pd.DataFrame(data=[14460928.0,12562766.0,16036268.0,17411098.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([14554447.], dtype=float32)

# %%
## For February 
x3=pd.DataFrame(data=[14534938.0,14460928.0,12562766.0,16036268.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([14609726.], dtype=float32)

# %%
## For march 
x3=pd.DataFrame(data=[14700662.0,14534938.0,14460928.0,12562766.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([14881443.], dtype=float32)

# %%
cat_c=df[['Category  C_Total Bottle','Month','Year']]
cat_c_2021=cat_c[cat_c['Year']==2021] 
cat_c_2021=cat_c_2021[['Category  C_Total Bottle','Month']]
cat_c_2021=cat_c_2021.groupby(by='Month').sum()
cat_c_2022=cat_c[cat_c['Year']==2022] 
cat_c_2022=cat_c_2022[['Category  C_Total Bottle','Month']]
cat_c_2022=cat_c_2022.groupby(by='Month').sum()
cat_c_final=pd.concat([cat_c_2021,cat_c_2022],axis=0)

cat_c_final['last_month_sale']=cat_c_final['Category  C_Total Bottle'].shift(+1)
cat_c_final['last_2_month_sale']=cat_c_final['Category  C_Total Bottle'].shift(+2)
cat_c_final['last_3_month_sale']=cat_c_final['Category  C_Total Bottle'].shift(+3)
cat_c_final['last_4_month_sale']=cat_c_final['Category  C_Total Bottle'].shift(+4)

cat_c_final=cat_c_final.dropna()

x=cat_c_final[['last_month_sale','last_2_month_sale','last_3_month_sale','last_4_month_sale']]
y=cat_c_final['Category  C_Total Bottle']

# %%
## HYPER PARAMETER OPTMIZATION

n_estimators=[100,500,900,1100,1500]
max_depth= [2,3,5,10,15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

hyperparameter_grid={
    'n_estimators':n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
}

import xgboost

regressor=xgboost.XGBRegressor()

random_cv= RandomizedSearchCV(estimator=regressor,
           param_distributions=hyperparameter_grid,
           cv=5,n_iter=50,
           scoring='neg_mean_absolute_error',n_jobs=4,
           verbose=5,
           return_train_score= True,
           random_state=42)

# %%
random_cv.fit(x,y)
random_cv.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=45)

# %%
XGBC = XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
             colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
             early_stopping_rounds=None, enable_categorical=False,
             eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
             importance_type=None, interaction_constraints='',
             learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
             max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=1,
             monotone_constraints='()', n_estimators=900, n_jobs=0,
             num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
             reg_lambda=1)
XGBC.fit(x_train,y_train)
y_pred = XGBC.predict(x_test)

# %%
cat_c_final
# Out:
#        Category  C_Total Bottle  last_month_sale  last_2_month_sale  \
# Month
# 8.0                        52.0             38.0              166.0
# 9.0                        20.0             52.0               38.0
# 10.0                        6.0             20.0               52.0
# 11.0                        0.0              6.0               20.0
# 12.0                        0.0              0.0                6.0
# 1.0                       214.0              0.0                0.0
# 2.0                     27648.0            214.0                0.0
# 3.0                     35544.0          27648.0              214.0
# 4.0                     59866.0          35544.0            27648.0
# 5.0                    104306.0          59866.0            35544.0
# 6.0                    116256.0         104306.0            59866.0
# 7.0                    168906.0         116256.0           104306.0
# 8.0                    267912.0         168906.0           116256.0
# ...

# %%
## For january
x3=pd.DataFrame(data=[448878.0,330482.0,409840.0,351778.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([330482.3], dtype=float32)

# %%
## For February 
x3=pd.DataFrame(data=[330482.3,448878.0,330482.0,409840.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([448877.94], dtype=float32)

# %%
## For march 
x3=pd.DataFrame(data=[448877.94,330482.3,448878.0,330482.0], index='last_month_sale last_2_month_sale last_3_month_sale last_4_month_sale'.split())
x3=x3.T
y_pred_1 = XGBC.predict(x3)
y_pred_1
# Out:
# array([330482.3], dtype=float32)

# %% [markdown]
# ## 5.Forecast the Sale volume for Q4 of FY 22-23 ( January to March 2023) Liquor Category wise
#
# ### For category-A
# #### January sales=2.1998082e+08
# #### February sales=2.1835141e+08
# #### March sales=2.22335e+08
#
# ### For category-B
# #### January sales=14534938.0
# #### February sales=14700662.0
# #### March sales=14822021.0
#
# ### For category-C
# #### January sales=330482.3
# #### February sales=448877.94
# #### March sales=330482.3

# %%
high_sale_amt=df[(df['District Name']=='District-C')][['Category  B_Sale Value','Month']]

# %%
high_sale_amt_1=high_sale_amt.groupby(by='Month').sum()

# %%
high_sale_amt_1.sort_values(by='Category  B_Sale Value',ascending=False)
# Out:
#        Category  B_Sale Value
# Month
# 6.0              1.024114e+09
# 5.0              1.006166e+09
# 4.0              9.814732e+08
# 8.0              8.359763e+08
# 10.0             7.405495e+08
# 7.0              7.293135e+08
# 9.0              7.277026e+08
# 12.0             6.804821e+08
# 11.0             5.811275e+08
# 3.0              4.261359e+08
# 1.0              3.595770e+08
# 2.0              3.237558e+08

# %% [markdown]
# ## 6.Which month has highest sale amount in District-C under Category B?
# ### july
